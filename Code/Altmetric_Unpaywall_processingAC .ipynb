# %%
# !pip install pandas matplotlib numpy seaborn scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/yls1/.local/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: matplotlib in /home/yls1/.local/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: numpy in /home/yls1/.local/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: seaborn in /home/yls1/.local/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /home/yls1/.local/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/yls1/.local/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/yls1/.local/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pillow>=8 in /home/yls1/.local/lib/python3.9/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/yls1/.local/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/yls1/.local/lib/python3.9/site-packages (from matplotlib) (6.4.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/yls1/.local/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/yls1/.local/lib/python3.9/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yls1/.local/lib/python3.9/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yls1/.local/lib/python3.9/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/yls1/.local/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/yls1/.local/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/yls1/.local/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/yls1/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /home/yls1/.local/lib/python3.9/site-packages
# sysconfig: /home/yls1/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None

# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import seaborn as sns
import sklearn
import requests
import json

# %%
# mcolors.BASE_COLORS #these colors can be called with a single character

# mcolors.TABLEAU_COLORS #the default color cycle colors

# mcolors.CSS4_COLORS #named colors also recognized in css

# mcolors.XKCD_COLORS #named colors from the xkcd survey

# %%
def Alt_data_check_clean(uni) : 
    # Read in Altmetric Data
    data = pd.read_csv(f"../Data/Alt/Altmetric_{uni}.csv", encoding = "utf-8")
    print(f"Read the {uni} Alt local data file!")
    
    data_extra = data.copy(deep=True)
    # data_extra = data_extra.dropna(axis=1, how='all')
    data_extra =data_extra.drop(columns =['Outlet or Author','Country','Mention Type','External Mention ID'],axis=1)
    print("trim the column")
    print("---Unique Numbers---")
    print(f"Unique DOI counts :{data_extra['DOI'].nunique()}")
    print(f"Unique Wiki Title counts :{data_extra['Mention Title'].nunique()}")
    print(f"Total data counts :{len(data_extra)}")
    
    print("---Check DOI ---")
    DOI_NA = data_extra[data_extra['DOI'].isna()==True ]
    DOI_Count = len(data_extra) - len(DOI_NA)
    #check  PubMedID exist when DOI is empty  
    PubMedID_exist =DOI_NA[DOI_NA["PubMed ID"].isna()==False]
    PubMedID_na =DOI_NA[DOI_NA["PubMed ID"].isna()==True]
    # ArXivID_exist =DOI_NA[DOI_NA["arXiv ID"].isna()==False]
    # ArXivID_na =DOI_NA[DOI_NA["arXiv ID"].isna()==True]
    
    print(f"There are {len(DOI_NA)} empty DOI")
    print(f"In those empty DOI, there are {len(PubMedID_exist)} with PubMedID ")
    print(f"There are {len(PubMedID_na)} withOUT PubMedID ")
    if len(PubMedID_na) > 0:
        print(PubMedID_na )
    
    print(f"Total : {len(data_extra)} data")
    print(" ")
    DOI_NA_table = pd.DataFrame(np.array([[DOI_Count, len(PubMedID_exist)], [len(DOI_NA), len(PubMedID_na)]]),
                       columns=['DOI', 'PubMedID'],index=["counts","empty"])
    print("Print DOIis empty _table")
    print(DOI_NA_table)

    print(" ")
    print("---Checking Affiliations--- ")
    Affil_without_uni = data_extra[~data_extra['Affiliations (GRID)'].str.contains(uni, na=False)]
    print(f"{len(Affil_without_uni)} data , not Uni included in Affiliations ")
    print(f" List the data not include {uni} ")
    print(Affil_without_uni)
    
    #check Mention Date >funder year
    date = data_extra["Mention Date"].str.split(" ",expand=True) 
    year = date[0].str.split("-",expand=True)[0]
    #print(f"Ealiest mention year : {min(year)}")

    #Check Mention Date _ date, format 
    data_extra[['Mention_date','Mention_time']] = data_extra["Mention Date"].str.split(" ",expand=True)  
    try:
        # This will raise an error if any date is not in the correct format
        data_extra['Mention_date'] = pd.to_datetime(data_extra['Mention_date'], format='%Y-%m-%d', errors='raise')
        print("All Mention dates are in the correct format.")
    except ValueError:
        print("Some dates are not in the correct format.",data_extra['Mention_date'])
            
    data_extra =data_extra.drop(columns =['Mention Date'],axis=1)
    
    # Publication Date
    try:
        # This will raise an error if any date is not in the correct format
        data_extra['Publication Date'] = pd.to_datetime(data_extra['Publication Date'], format='%Y-%m-%d', errors='raise')
        print("All Publication dates are in the correct format.")
    except ValueError:
        print("Some dates are not in the correct format.",data_extra['Publication Date'])
    #Mention URL
    print("Any empty URL")
    print(data_extra[data_extra['Mention URL'].isna()== True])

    #Wiki_Language code from url  
    lan = data_extra["Mention URL"]
    lan =lan.str.split("//",expand=True)[1]
    Wiki_Lang_code = lan.str.split(".",expand=True)[0]
    data_extra['Wiki_Language'] = Wiki_Lang_code 
    print(f"Top 10 using Language") #or Top 15
    print(data_extra['Wiki_Language'].value_counts()[:10]) 

    # Altmetric Attention Score
    # # print(data_extra['Altmetric Attention Score'].isna().unique())
    # try:
    #     # This will raise an error if any value is not an integer
    #     data_extra['Altmetric Attention Score'] = pd.to_numeric(data_extra['Altmetric Attention Score'], downcast='integer', errors='raise')
    #     print("All values in the column are integers.")
    # except ValueError:
    #     print("Some values in the column are not integers.")
    #Subjects (FoR) _spilt grid and subject or not))

    #Drop empty DOI
    if len(DOI_NA) > 0:
        data_cleaned =  data_extra.dropna(subset=['DOI'])
        data_cleaned = data_cleaned[data_cleaned['DOI'].str.strip()!='']
        data_cleaned.reset_index(drop=True,inplace=True)
    else :
        data_cleaned = data_extra

    print("Last Cleaned Data")
    # print(data_cleaned)
    return data_cleaned

# %%
def uni_group(x) :
    grouping_type = ""
    g1 = ["Glasgow School of Art","Royal Conservatoire of Scotland","Scotland's Rural College"]
    g2 = ["University of Edinburgh","University of Glasgow","University of St Andrews","University of Aberdeen"]
    g3 = ["University of Dundee","Heriot-Watt University","University of Strathclyde","University of Stirling"]
    g4 = ["Abertay University","Glasgow Caledonian University","Edinburgh Napier University","Queen Margaret University",
          "University of the Highlands and Islands","University of the West of Scotland","Robert Gordon University"]
    if x in g1 :
        grouping_type = "Specialist" ;
    elif x in g2 :
        grouping_type = "Ancient" ;
    elif x in g3 :
        grouping_type = "Chartered" ;
    elif x in g4 :
        grouping_type = "Modern" ;
    else :
        grouping_type = f"No Group_{u}"
    return grouping_type

# %%
def Unpaywalldata(uni,data_cl):

    #add info
    Uni, Grouping = [],[]
    group_type = uni_group(uni)
    #Unpaywall data
    Is_OA,OA_Status = [], []
    Genre ,title, OA_Locations, License_bestOA = [], [], [], []

    #API _all DOI unpaywall data 
    for j in range(len(data_cl)):
        Uni.append(uni)
        Grouping.append(group_type)
        response_API = requests.get(f"https://api.unpaywall.org/v2/{data_cl['DOI'][j]}?email=unpaywall_01@example.com")
        #print(response_API.status_code)
        if response_API.status_code ==200 :
            Unpaywall_data= response_API.text
            parse_json = json.loads(Unpaywall_data)
            active_case = parse_json
            Is_OA.append(active_case['is_oa'])
            OA_Status.append(active_case['oa_status'])
            Genre.append(active_case['genre'])
            title.append(active_case['title'])
            OA_Locations.append(active_case['oa_locations'])
            if active_case['is_oa'] is True :
                License_bestOA.append(active_case['best_oa_location']['license'])
            else :
                License_bestOA.append('Not OA')
        else :
            Is_OA.append('notFound')
            OA_Status.append(response_API.status_code)
            Genre.append('notFound')
            title.append('notFound')
            OA_Locations.append('notFound')
            License_bestOA.append('notFound')
           
            
    #Keep key data
    #clean and turn to dataframe
    Is_OA = pd.DataFrame(Is_OA, columns = ['OA_status'])
    Uni = pd.DataFrame(Uni , columns = ['University'])
    Grouping = pd.DataFrame(Grouping, columns = ['Group'])
    OA_Status = pd.DataFrame(OA_Status , columns = ['OA_Type'])
    #---more information
    Genre = pd.DataFrame(Genre , columns = ['Genre'])
    title = pd.DataFrame(title , columns = ['Title'])
    OA_Locations = pd.Series(OA_Locations)
    OA_Locations = pd.DataFrame(OA_Locations , columns = ['OA_Locations'])
    License_bestOA = pd.DataFrame(License_bestOA , columns = ['License_bestOA'])
    
    
    OA_data= pd.concat([Is_OA,OA_Status,Genre,title,OA_Locations,License_bestOA,Uni,Grouping],axis = 1)
    #print(OA_data)
    New_data = pd.concat([data_cl,OA_data],axis = 1)
    # print(New_data)
    # # New_data.to_csv(f"{x}_AltOA.csv")
    # New_data.to_csv(f"../Data/Unpaywall/New/n_{uni}_AltOA.csv",index=False)
    print("Finish dowonload")
    
    return  New_data

# %% [markdown]
# ### check unpaywall new data

# %%
def unpaywall_df_check(ndf) :
    # print(ndf.info())
    print("Check OA_status")
    print("Not found OA_status")
    if len(ndf[ndf['OA_status'].isna() == False]) ==0 :
        print("There is not empty OA_status")
    else  :
        print(ndf[ndf['OA_status'].isna()== True])
    
    #Check 'OA_status' is either True or False
    print(ndf['OA_status'].unique())
    desired_bool = [False, True]
    error_status = ndf[~ndf["OA_status"].isin(desired_bool)]
    print(f"There are TOTAL : {error_status.shape[0]} Data  cannot find through Unpaywall.")
    print(f"There are {ndf[ndf['OA_status']=='notFound'].shape[0]} Data  cannot find through Unpaywall.")
    #List data entries which "notFound" for further check
    print(ndf[ndf['OA_status']=="notFound"][['DOI','OA_Type']])
    
    #Check 'OA_Type' is only those 5 types ['closed','bronze','green','gold','hybrid']
    print(ndf['OA_Type'].unique())
    desired_Type= ['closed','bronze','green','gold','hybrid']
    error_data = ndf[~ndf["OA_Type"].isin(desired_Type)]
    print(" ")
    #List data entries which not expected OA Type for further check
    #confirm the unexpected OA_status and OA_Type is the same data entry 
    print("error data _list (Doi)")
    print(error_data[["DOI",'OA_status','OA_Type',"Mention Title"]])
    print("------")
    
    #1 Cleaned Data (remove empty DOI/error status entries)
    cl_data = ndf[ndf['OA_status']!= "notFound"]
    print("-- Cleaned Data count --")
    print(f"Total catation : {cl_data.shape[0]}")
    print("University OA_ Status count")
    print(cl_data['OA_status'].value_counts())
    print("University OA_ Type count")
    print(cl_data['OA_Type'].value_counts())
    print("------")
    
    #Explore Duplication 
    full_duplicates = cl_data[cl_data.duplicated(subset=["DOI","Mention Title","Mention URL",'Mention_date','Wiki_Language'],keep=False)]
    print("About truly duplicates")
    print(f"There are {full_duplicates['DOI'].nunique()} unique DOI in Duplicate list ")
    print(f"There are {full_duplicates['Mention Title'].nunique()} unique Wiki Title in Duplicate list ")
    print(f"There are Total : {len(full_duplicates)} data in Duplicate list")
    print(" ")
    
    
    duplicates = cl_data[cl_data.duplicated(subset=["DOI","Mention Title",'Mention_date','Wiki_Language'],keep=False)]
    print("About potential duplicates")
    print(f"There are {duplicates['DOI'].nunique()} unique DOI in  potential Duplicate list ")
    print(f"There are {duplicates['Mention Title'].nunique()} unique Wiki Title in potential Duplicate list ")
    print(f"There are Total : {len(duplicates)} data in potential Duplicate list ")
    
    
    #2 De-truly Duplication Data
    No_du_data = cl_data.drop_duplicates(subset=["DOI","Mention Title","Mention URL",'Mention_date','Wiki_Language'],keep="last")
    No_du_data = No_du_data[No_du_data['OA_status']!= "notFound"]
    print(f"De-truly Duplication Total catation : {No_du_data.shape[0]}")
    #3 De-potential Duplicaion Data
    No_pdu_data = cl_data.drop_duplicates(subset=["DOI","Mention Title",'Mention_date','Wiki_Language'],keep="last")
    No_pdu_data = No_pdu_data[No_pdu_data['OA_status']!= "notFound"]
    print(f"De-potential Duplication Total catation : {No_pdu_data.shape[0]}")
    
    print(" ")
    print("Show all data count and percentage")
    def calculate_counts_and_percentages(data):     
        oaStatus_counts = data['OA_status'].value_counts()
        oaStatus_percentages = data['OA_status'].value_counts(normalize = True)*100
        
        OpenOA = data[data['OA_status']==True]
        OpenOAType_counts = OpenOA ['OA_Type'].value_counts()
        OpenOAType_percentages  = OpenOA ['OA_Type'].value_counts(normalize = True)*100
    
        OA_status_table = pd.DataFrame({
           'count':oaStatus_counts ,
           'percentage':oaStatus_percentages
        })
    
        OA_type_table = pd.DataFrame({
           'count':OpenOAType_counts ,
           'percentage':OpenOAType_percentages
        })
        
        data_countandpercent = pd.concat([OA_status_table,OA_type_table] ,keys=['OA_status','OA_Type'])
        return data_countandpercent
    
    #1+2+3    
    combined_data = pd.concat([calculate_counts_and_percentages(cl_data),calculate_counts_and_percentages(No_du_data),calculate_counts_and_percentages(No_pdu_data)] ,axis=1)
    
    print(combined_data)

# %%
# Group_s = ["Glasgow School of Art","Royal Conservatoire of Scotland","Scotland's Rural College"]
# Group_M = ["Abertay University","Queen Margaret University","Glasgow Caledonian University","Edinburgh Napier University",
#       "University of the West of Scotland","Robert Gordon University","University of the Highlands and Islands"]
# Group_A = ["University of Edinburgh","University of Glasgow","University of St Andrews","University of Aberdeen"]
# Group_C = ["University of Dundee","Heriot-Watt University","University of Strathclyde","University of Stirling"]

# %%
Group_C = ["University of Dundee","Heriot-Watt University","University of Strathclyde","University of Stirling"]
for uni in Group_C :
    print(f"!!{uni}_Start")
    data_cleaned  = Alt_data_check_clean(uni) 
    New_data = Unpaywalldata(uni,data_cleaned)
    print("+++------------------------")
    print('check unpaywall new data')
    # print( New_data.info())
    unpaywall_df_check(New_data)
    print(f"{uni}_done")
    print("------------------------")
    print(" ")
# Out:
# !!University of Dundee_Start
# Read the University of Dundee Alt local data file!
# trim the column
# ---Unique Numbers---
# Unique DOI counts :2155
# Unique Wiki Title counts :4678
# Total data counts :6876
# ---Check DOI ---
# There are 35 empty DOI
# In those empty DOI, there are 35 with PubMedID
# There are 0 withOUT PubMedID
# Total : 6876 data
#
# Print DOIis empty _table
#          DOI  PubMedID
# counts  6841        35
# empty     35         0
#
# ---Checking Affiliations---
# 0 data , not Uni included in Affiliations
#  List the data not include University of Dundee
# Empty DataFrame
# Columns: [Mention Date, Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names]
# Index: []
#
# [0 rows x 26 columns]
# All Mention dates are in the correct format.
# All Publication dates are in the correct format.
# Any empty URL
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time]
# Index: []
#
# [0 rows x 27 columns]
# Top 10 using Language
# Wiki_Language
# en    2952
# ar     587
# ja     327
# es     280
# uk     254
# zh     225
# it     222
# fr     207
# ru     198
# pt     170
# Name: count, dtype: int64
# Last Cleaned Data
# Finish dowonload
# +++------------------------
# check unpaywall new data
# Check OA_status
# Not found OA_status
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time, Wiki_Language, OA_status, OA_Type, Genre, Title, OA_Locations, License_bestOA, University, Group]
# Index: []
#
# [0 rows x 36 columns]
# [False True 'notFound']
# There are TOTAL : 1 Data  cannot find through Unpaywall.
# There are 1 Data  cannot find through Unpaywall.
#                                                     DOI OA_Type
# 2769  10.1002/1521-1878(200011)22:11<997::aid-bies6>...     422
# ['closed' 'gold' 'hybrid' 'bronze' 'green' 422]
#
# error data _list (Doi)
#                                                     DOI OA_status OA_Type  \
# 2769  10.1002/1521-1878(200011)22:11<997::aid-bies6>...  notFound     422
#
#         Mention Title
# 2769  Phycodnaviridae
# ------
# -- Cleaned Data count --
# Total catation : 6840
# University OA_ Status count
# OA_status
# True     4316
# False    2524
# Name: count, dtype: int64
# University OA_ Type count
# OA_Type
# closed    2524
# bronze    1524
# green     1256
# hybrid    1108
# gold       428
# Name: count, dtype: int64
# ------
# About truly duplicates
# There are 0 unique DOI in Duplicate list
# There are 0 unique Wiki Title in Duplicate list
# There are Total : 0 data in Duplicate list
#
# About potential duplicates
# There are 46 unique DOI in  potential Duplicate list
# There are 42 unique Wiki Title in potential Duplicate list
# There are Total : 110 data in potential Duplicate list
# De-truly Duplication Total catation : 6840
# De-potential Duplication Total catation : 6780
#
# Show all data count and percentage
#                   count  percentage  count  percentage  count  percentage
# OA_status True     4316   63.099415   4316   63.099415   4271   62.994100
#           False    2524   36.900585   2524   36.900585   2509   37.005900
# OA_Type   bronze   1524   35.310473   1524   35.310473   1511   35.378132
#           green    1256   29.101019   1256   29.101019   1243   29.103255
#           hybrid   1108   25.671918   1108   25.671918   1102   25.801920
#           gold      428    9.916589    428    9.916589    415    9.716694
# University of Dundee_done
# ------------------------
#
# !!Heriot-Watt University_Start
# Read the Heriot-Watt University Alt local data file!
# trim the column
# ---Unique Numbers---
# Unique DOI counts :512
# Unique Wiki Title counts :936
# Total data counts :1112
# ---Check DOI ---
# There are 0 empty DOI
# In those empty DOI, there are 0 with PubMedID
# There are 0 withOUT PubMedID
# Total : 1112 data
#
# Print DOIis empty _table
#          DOI  PubMedID
# counts  1112         0
# empty      0         0
#
# ---Checking Affiliations---
# 0 data , not Uni included in Affiliations
#  List the data not include Heriot-Watt University
# Empty DataFrame
# Columns: [Mention Date, Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names]
# Index: []
#
# [0 rows x 26 columns]
# All Mention dates are in the correct format.
# All Publication dates are in the correct format.
# Any empty URL
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time]
# Index: []
#
# [0 rows x 27 columns]
# Top 10 using Language
# Wiki_Language
# en    566
# es     43
# de     40
# fr     40
# ar     35
# zh     33
# uk     33
# pt     32
# ja     31
# fa     29
# Name: count, dtype: int64
# Last Cleaned Data
# Finish dowonload
# +++------------------------
# check unpaywall new data
# Check OA_status
# Not found OA_status
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time, Wiki_Language, OA_status, OA_Type, Genre, Title, OA_Locations, License_bestOA, University, Group]
# Index: []
#
# [0 rows x 36 columns]
# [False  True]
# There are TOTAL : 0 Data  cannot find through Unpaywall.
# There are 0 Data  cannot find through Unpaywall.
# Empty DataFrame
# Columns: [DOI, OA_Type]
# Index: []
# ['closed' 'hybrid' 'gold' 'green' 'bronze']
#
# error data _list (Doi)
# Empty DataFrame
# Columns: [DOI, OA_status, OA_Type, Mention Title]
# Index: []
# ------
# -- Cleaned Data count --
# Total catation : 1112
# University OA_ Status count
# OA_status
# True     602
# False    510
# Name: count, dtype: int64
# University OA_ Type count
# OA_Type
# closed    510
# green     224
# gold      185
# hybrid    119
# bronze     74
# Name: count, dtype: int64
# ------
# About truly duplicates
# There are 0 unique DOI in Duplicate list
# There are 0 unique Wiki Title in Duplicate list
# There are Total : 0 data in Duplicate list
#
# About potential duplicates
# There are 13 unique DOI in  potential Duplicate list
# There are 13 unique Wiki Title in potential Duplicate list
# There are Total : 27 data in potential Duplicate list
# De-truly Duplication Total catation : 1112
# De-potential Duplication Total catation : 1098
#
# Show all data count and percentage
#                   count  percentage  count  percentage  count  percentage
# OA_status True      602   54.136691    602   54.136691    599   54.553734
#           False     510   45.863309    510   45.863309    499   45.446266
# OA_Type   green     224   37.209302    224   37.209302    224   37.395659
#           gold      185   30.730897    185   30.730897    184   30.717863
#           hybrid    119   19.767442    119   19.767442    119   19.866444
#           bronze     74   12.292359     74   12.292359     72   12.020033
# Heriot-Watt University_done
# ------------------------
#
# !!University of Strathclyde_Start
# Read the University of Strathclyde Alt local data file!
# trim the column
# ---Unique Numbers---
# Unique DOI counts :1247
# Unique Wiki Title counts :2501
# Total data counts :3486
# ---Check DOI ---
# There are 8 empty DOI
# In those empty DOI, there are 8 with PubMedID
# There are 0 withOUT PubMedID
# Total : 3486 data
#
# Print DOIis empty _table
#          DOI  PubMedID
# counts  3478         8
# empty      8         0
#
# ---Checking Affiliations---
# 0 data , not Uni included in Affiliations
#  List the data not include University of Strathclyde
# Empty DataFrame
# Columns: [Mention Date, Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names]
# Index: []
#
# [0 rows x 26 columns]
# All Mention dates are in the correct format.
# All Publication dates are in the correct format.
# Any empty URL
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time]
# Index: []
#
# [0 rows x 27 columns]
# Top 10 using Language
# Wiki_Language
# en    1460
# zh     171
# es     148
# ar     146
# fr     138
# ru     119
# vi     112
# pt     110
# de     110
# uk     104
# Name: count, dtype: int64
# Last Cleaned Data
# Finish dowonload
# +++------------------------
# check unpaywall new data
# Check OA_status
# Not found OA_status
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time, Wiki_Language, OA_status, OA_Type, Genre, Title, OA_Locations, License_bestOA, University, Group]
# Index: []
#
# [0 rows x 36 columns]
# [False  True]
# There are TOTAL : 0 Data  cannot find through Unpaywall.
# There are 0 Data  cannot find through Unpaywall.
# Empty DataFrame
# Columns: [DOI, OA_Type]
# Index: []
# ['closed' 'gold' 'hybrid' 'bronze' 'green']
#
# error data _list (Doi)
# Empty DataFrame
# Columns: [DOI, OA_status, OA_Type, Mention Title]
# Index: []
# ------
# -- Cleaned Data count --
# Total catation : 3478
# University OA_ Status count
# OA_status
# True     2379
# False    1099
# Name: count, dtype: int64
# University OA_ Type count
# OA_Type
# closed    1099
# hybrid     878
# green      581
# bronze     563
# gold       357
# Name: count, dtype: int64
# ------
# About truly duplicates
# There are 0 unique DOI in Duplicate list
# There are 0 unique Wiki Title in Duplicate list
# There are Total : 0 data in Duplicate list
#
# About potential duplicates
# There are 30 unique DOI in  potential Duplicate list
# There are 28 unique Wiki Title in potential Duplicate list
# There are Total : 62 data in potential Duplicate list
# De-truly Duplication Total catation : 3478
# De-potential Duplication Total catation : 3446
#
# Show all data count and percentage
#                   count  percentage  count  percentage  count  percentage
# OA_status True     2379   68.401380   2379   68.401380   2361   68.514219
#           False    1099   31.598620   1099   31.598620   1085   31.485781
# OA_Type   hybrid    878   36.906263    878   36.906263    874   37.018213
#           green     581   24.422026    581   24.422026    578   24.481152
#           bronze    563   23.665406    563   23.665406    554   23.464634
#           gold      357   15.006305    357   15.006305    355   15.036002
# University of Strathclyde_done
# ------------------------
#
# !!University of Stirling_Start
# Read the University of Stirling Alt local data file!
# trim the column
# ---Unique Numbers---
# Unique DOI counts :981
# Unique Wiki Title counts :3158
# Total data counts :3609
# ---Check DOI ---
# There are 5 empty DOI
# In those empty DOI, there are 5 with PubMedID
# There are 0 withOUT PubMedID
# Total : 3609 data
#
# Print DOIis empty _table
#          DOI  PubMedID
# counts  3604         5
# empty      5         0
#
# ---Checking Affiliations---
# 0 data , not Uni included in Affiliations
#  List the data not include University of Stirling
# Empty DataFrame
# Columns: [Mention Date, Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names]
# Index: []
#
# [0 rows x 26 columns]
# All Mention dates are in the correct format.
# All Publication dates are in the correct format.
# Any empty URL
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time]
# Index: []
#
# [0 rows x 27 columns]
# Top 10 using Language
# Wiki_Language
# zh    1275
# en    1138
# es     139
# fr     125
# ar     108
# de      72
# sr      69
# pt      67
# it      63
# ja      54
# Name: count, dtype: int64
# Last Cleaned Data
# Finish dowonload
# +++------------------------
# check unpaywall new data
# Check OA_status
# Not found OA_status
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time, Wiki_Language, OA_status, OA_Type, Genre, Title, OA_Locations, License_bestOA, University, Group]
# Index: []
#
# [0 rows x 36 columns]
# [True False 'notFound']
# There are TOTAL : 2 Data  cannot find through Unpaywall.
# There are 2 Data  cannot find through Unpaywall.
#                         DOI OA_Type
# 3070  10-1123/jsr.2014-0325     404
# 3565  10.1136/vr.147.23.662     404
# ['gold' 'hybrid' 'closed' 'green' 'bronze' 404]
#
# error data _list (Doi)
#                         DOI OA_status OA_Type        Mention Title
# 3070  10-1123/jsr.2014-0325  notFound     404      Tensiomyography
# 3565  10.1136/vr.147.23.662  notFound     404  Streptococcus iniae
# ------
# -- Cleaned Data count --
# Total catation : 3602
# University OA_ Status count
# OA_status
# True     2474
# False    1128
# Name: count, dtype: int64
# University OA_ Type count
# OA_Type
# hybrid    1416
# closed    1128
# green      505
# bronze     293
# gold       260
# Name: count, dtype: int64
# ------
# About truly duplicates
# There are 0 unique DOI in Duplicate list
# There are 0 unique Wiki Title in Duplicate list
# There are Total : 0 data in Duplicate list
#
# About potential duplicates
# There are 20 unique DOI in  potential Duplicate list
# There are 21 unique Wiki Title in potential Duplicate list
# There are Total : 45 data in potential Duplicate list
# De-truly Duplication Total catation : 3602
# De-potential Duplication Total catation : 3579
#
# Show all data count and percentage
#                   count  percentage  count  percentage  count  percentage
# OA_status True     2474   68.684064   2474   68.684064   2459   68.706343
#           False    1128   31.315936   1128   31.315936   1120   31.293657
# OA_Type   hybrid   1416   57.235247   1416   57.235247   1412   57.421716
#           green     505   20.412288    505   20.412288    502   20.414803
#           bronze    293   11.843169    293   11.843169    288   11.712078
#           gold      260   10.509297    260   10.509297    257   10.451403
# University of Stirling_done
# ------------------------

# %%
Group_A = ["University of Aberdeen","University of St Andrews","University of Edinburgh","University of Glasgow"]
for uni in Group_A :
    print(f"!!{uni}_Start")
    data_cleaned  = Alt_data_check_clean(uni) 
    New_data = Unpaywalldata(uni,data_cleaned)
    print("+++------------------------")
    print('check unpaywall new data')
    # print( New_data.info())
    unpaywall_df_check(New_data)
    print(f"{uni}_done")
    print("------------------------")
    print(" ")
# Out:
# !!University of Aberdeen_Start
# Read the University of Aberdeen Alt local data file!
# trim the column
# ---Unique Numbers---
# Unique DOI counts :2888
# Unique Wiki Title counts :6368
# Total data counts :8226
# ---Check DOI ---
# There are 57 empty DOI
# In those empty DOI, there are 57 with PubMedID
# There are 0 withOUT PubMedID
# Total : 8226 data
#
# Print DOIis empty _table
#          DOI  PubMedID
# counts  8169        57
# empty     57         0
#
# ---Checking Affiliations---
# 0 data , not Uni included in Affiliations
#  List the data not include University of Aberdeen
# Empty DataFrame
# Columns: [Mention Date, Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names]
# Index: []
#
# [0 rows x 26 columns]
# All Mention dates are in the correct format.
# All Publication dates are in the correct format.
# Any empty URL
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time]
# Index: []
#
# [0 rows x 27 columns]
# Top 10 using Language
# Wiki_Language
# en    3544
# es     444
# fr     360
# ar     360
# de     328
# zh     276
# it     265
# ru     214
# sr     210
# pt     208
# Name: count, dtype: int64
# Last Cleaned Data
# Finish dowonload
# +++------------------------
# check unpaywall new data
# Check OA_status
# Not found OA_status
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time, Wiki_Language, OA_status, OA_Type, Genre, Title, OA_Locations, License_bestOA, University, Group]
# Index: []
#
# [0 rows x 36 columns]
# [True False 'notFound']
# There are TOTAL : 7 Data  cannot find through Unpaywall.
# There are 7 Data  cannot find through Unpaywall.
#                                                     DOI OA_Type
# 1780                           10.1136/jnnp.2002.008805     404
# 2227                     1396674/dot.2009.45.10.1416583     404
# 4091                     1396674/dot.2009.45.10.1416583     404
# 4556  10.1002/1097-0061(20000315)16:4<325::aid-yea53...     422
# 5740                     1396674/dot.2009.45.10.1416583     404
# 6233                        10.1359/jbmr.2004.19.10.165     404
# 6808                     1396674/dot.2009.45.10.1416583     404
# ['gold' 'green' 'closed' 'bronze' 'hybrid' 404 422]
#
# error data _list (Doi)
#                                                     DOI OA_status OA_Type  \
# 1780                           10.1136/jnnp.2002.008805  notFound     404
# 2227                     1396674/dot.2009.45.10.1416583  notFound     404
# 4091                     1396674/dot.2009.45.10.1416583  notFound     404
# 4556  10.1002/1097-0061(20000315)16:4<325::aid-yea53...  notFound     422
# 5740                     1396674/dot.2009.45.10.1416583  notFound     404
# 6233                        10.1359/jbmr.2004.19.10.165  notFound     404
# 6808                     1396674/dot.2009.45.10.1416583  notFound     404
#
#             Mention Title
# 1780             Dementia
# 2227     Алергія на холод
# 4091            شرى البرد
# 4556                白色念珠菌
# 5740    شرى البرد العائلي
# 6233  Aphelion (logiciel)
# 6808       Cold urticaria
# ------
# -- Cleaned Data count --
# Total catation : 8162
# University OA_ Status count
# OA_status
# True     4581
# False    3581
# Name: count, dtype: int64
# University OA_ Type count
# OA_Type
# closed    3581
# bronze    1642
# green     1447
# gold       776
# hybrid     716
# Name: count, dtype: int64
# ------
# About truly duplicates
# There are 0 unique DOI in Duplicate list
# There are 0 unique Wiki Title in Duplicate list
# There are Total : 0 data in Duplicate list
#
# About potential duplicates
# There are 60 unique DOI in  potential Duplicate list
# There are 77 unique Wiki Title in potential Duplicate list
# There are Total : 169 data in potential Duplicate list
# De-truly Duplication Total catation : 8162
# De-potential Duplication Total catation : 8071
#
# Show all data count and percentage
#                   count  percentage  count  percentage  count  percentage
# OA_status True     4581   56.125950   4581   56.125950   4531   56.139264
#           False    3581   43.874050   3581   43.874050   3540   43.860736
# OA_Type   bronze   1642   35.843702   1642   35.843702   1630   35.974399
#           green    1447   31.586990   1447   31.586990   1441   31.803134
#           gold      776   16.939533    776   16.939533    761   16.795409
#           hybrid    716   15.629775    716   15.629775    699   15.427058
# University of Aberdeen_done
# ------------------------
#
# !!University of St Andrews_Start
# Read the University of St Andrews Alt local data file!
# trim the column
# ---Unique Numbers---
# Unique DOI counts :2962
# Unique Wiki Title counts :6451
# Total data counts :9858
# ---Check DOI ---
# There are 6 empty DOI
# In those empty DOI, there are 6 with PubMedID
# There are 0 withOUT PubMedID
# Total : 9858 data
#
# Print DOIis empty _table
#          DOI  PubMedID
# counts  9852         6
# empty      6         0
#
# ---Checking Affiliations---
# 18 data , not Uni included in Affiliations
#  List the data not include University of St Andrews
#              Mention Date                 Mention Title  \
# 240   2024-03-16 21:22:19                Болест знојења
# 290   2024-02-25 17:34:34                Sudor anglicus
# 766   2023-10-09 22:38:46                Gender-Pay-Gap
# 943   2023-08-05 19:56:21                 ثقافة الحيوان
# 2506  2022-04-25 19:00:41     Terleme hastalığı salgını
# 2695  2022-02-24 15:42:28                Animal culture
# 2773  2022-02-04 13:33:23                  Guy Thwaites
# 3925  2021-02-18 10:25:02                        Dacite
# 4283  2020-11-11 18:39:13                    Rhyodacite
# 4313  2020-11-04 16:34:21       Igneous differentiation
# 5652  2019-05-12 04:24:27                          人际吸引
# 6054  2018-10-12 15:14:36             انجذاب جنسي وراثي
# 6541  2018-01-19 05:57:53      Interpersonal attraction
# 7071  2017-04-13 03:16:47       Atração sexual genética
# 8504  2013-07-08 01:44:18             Sweating sickness
# 8744  2012-10-10 09:26:48           Malattia del sudore
# 8921  2011-12-24 17:05:33  Attrazione sessuale genetica
# 9710  2008-06-07 22:09:45              Timothy Chambers
#
#                                             Mention URL  \
# 240   http://sr.wikipedia.org/?diff=prev&oldid=27491...
# 290   http://pt.wikipedia.org/?diff=prev&oldid=67538...
# 766   http://de.wikipedia.org/?diff=prev&oldid=23802...
# 943   http://ar.wikipedia.org/?diff=prev&oldid=63643...
# 2506  http://tr.wikipedia.org/?diff=prev&oldid=27641...
# 2695  http://en.wikipedia.org/?diff=prev&oldid=10737...
# 2773  http://en.wikipedia.org/?diff=prev&oldid=10698...
# 3925  http://en.wikipedia.org/?diff=prev&oldid=10074...
# 4283  http://en.wikipedia.org/?diff=prev&oldid=98819...
# 4313  http://en.wikipedia.org/?diff=prev&oldid=98705...
# 5652  http://zh.wikipedia.org/?diff=prev&oldid=54382...
# 6054  http://ar.wikipedia.org/?diff=prev&oldid=30996...
# 6541  http://en.wikipedia.org/?diff=prev&oldid=82123...
# 7071  http://pt.wikipedia.org/?diff=prev&oldid=48536...
# 8504  http://en.wikipedia.org/?diff=prev&oldid=56331...
# 8744  http://it.wikipedia.org/?diff=prev&oldid=53102...
# 8921  http://it.wikipedia.org/?diff=prev&oldid=45857...
# 9710  http://en.wikipedia.org/?diff=prev&oldid=21783...
#
#                                   Research Output Title  \
# 240   The English sweating sickness, 1485–1551: A vi...
# 290   The English sweating sickness, 1485–1551: A vi...
# 766   A longitudinal analysis of family migration an...
# 943   Cultural traditions across a migratory network...
# 2506  The English sweating sickness, 1485–1551: A vi...
# 2695  Cultural traditions across a migratory network...
# 2773  The English sweating sickness, 1485–1551: A vi...
# 3925  Pre-eruptive magma mixing in ash-flow deposits...
# 4283  Pre-eruptive magma mixing in ash-flow deposits...
# 4313  Pre-eruptive magma mixing in ash-flow deposits...
# 5652  Computer graphic studies of the role of facial...
# 6054  Computer graphic studies of the role of facial...
# 6541  Computer graphic studies of the role of facial...
# 7071  Computer graphic studies of the role of facial...
# 8504  The English sweating sickness, 1485–1551: A vi...
# 8744  The English sweating sickness, 1485–1551: A vi...
# 8921  Computer graphic studies of the role of facial...
# 9710  On being in a quandary. Relativism vagueness l...
#
#                        Journal/Collection Title  \
# 240                             Medical History
# 290                             Medical History
# 766                                  Demography
# 943                          Scientific Reports
# 2506                            Medical History
# 2695                         Scientific Reports
# 2773                            Medical History
# 3925  Contributions to Mineralogy and Petrology
# 4283  Contributions to Mineralogy and Petrology
# 4313  Contributions to Mineralogy and Petrology
# 5652                         Current Psychology
# 6054                         Current Psychology
# 6541                         Current Psychology
# 7071                         Current Psychology
# 8504                            Medical History
# 8744                            Medical History
# 8921                         Current Psychology
# 9710                                       Mind
#
#                   Authors at my Institution  \
# 240                                     NaN
# 290                                     NaN
# 766                                     NaN
# 943   Gaggiotti, Oscar E.; Carroll, Emma L.
# 2506                                    NaN
# 2695  Gaggiotti, Oscar E.; Carroll, Emma L.
# 2773                                    NaN
# 3925                    Donaldson, Colin H.
# 4283                    Donaldson, Colin H.
# 4313                    Donaldson, Colin H.
# 5652                                    NaN
# 6054                                    NaN
# 6541                                    NaN
# 7071                                    NaN
# 8504                                    NaN
# 8744                                    NaN
# 8921                                    NaN
# 9710                        Wright, Crispin
#
#                                             Departments Output Type  \
# 240                                                 NaN     Article
# 290                                                 NaN     Article
# 766                                                 NaN     Article
# 943   Units, Institutes, Research Centres and Resear...     Article
# 2506                                                NaN     Article
# 2695  Units, Institutes, Research Centres and Resear...     Article
# 2773                                                NaN     Article
# 3925  1. Schools; School of Geography and Geoscience...     Article
# 4283  1. Schools; School of Geography and Geoscience...     Article
# 4313  1. Schools; School of Geography and Geoscience...     Article
# 5652                                                NaN     Article
# 6054                                                NaN     Article
# 6541                                                NaN     Article
# 7071                                                NaN     Article
# 8504                                                NaN     Article
# 8744                                                NaN     Article
# 8921                                                NaN     Article
# 9710  1. Schools; Philosophy; School of Philosophica...     Article
#
#                                          Subjects (FoR)  \
# 240   43 History, Heritage and Archaeology; 4303 His...
# 290   43 History, Heritage and Archaeology; 4303 His...
# 766                   44 Human Society; 4403 Demography
# 943   31 Biological Sciences; 3103 Ecology; 3105 Gen...
# 2506  43 History, Heritage and Archaeology; 4303 His...
# 2695  31 Biological Sciences; 3103 Ecology; 3105 Gen...
# 2773  43 History, Heritage and Archaeology; 4303 His...
# 3925  37 Earth Sciences; 3703 Geochemistry; 3705 Geo...
# 4283  37 Earth Sciences; 3703 Geochemistry; 3705 Geo...
# 4313  37 Earth Sciences; 3703 Geochemistry; 3705 Geo...
# 5652  52 Psychology; 5202 Biological Psychology; 520...
# 6054  52 Psychology; 5202 Biological Psychology; 520...
# 6541  52 Psychology; 5202 Biological Psychology; 520...
# 7071  52 Psychology; 5202 Biological Psychology; 520...
# 8504  43 History, Heritage and Archaeology; 4303 His...
# 8744  43 History, Heritage and Archaeology; 4303 His...
# 8921  52 Psychology; 5202 Biological Psychology; 520...
# 9710  50 Philosophy and Religious Studies; 5002 Hist...
#
#                                     Affiliations (GRID)  ...  \
# 240                              St. Andrews University  ...
# 290                              St. Andrews University  ...
# 766   St. Andrews University; University of Connecticut  ...
# 943   Durham University; Macquarie University; Orego...  ...
# 2506                             St. Andrews University  ...
# 2695  Durham University; Macquarie University; Orego...  ...
# 2773                             St. Andrews University  ...
# 3925  Durham University; St. Andrews University; Tri...  ...
# 4283  Durham University; St. Andrews University; Tri...  ...
# 4313  Durham University; St. Andrews University; Tri...  ...
# 5652                             St. Andrews University  ...
# 6054                             St. Andrews University  ...
# 6541                             St. Andrews University  ...
# 7071                             St. Andrews University  ...
# 8504                             St. Andrews University  ...
# 8744                             St. Andrews University  ...
# 8921                             St. Andrews University  ...
# 9710                             St. Andrews University  ...
#
#                                            URI   PubMed ID PubMedCentral ID  \
# 240                                        NaN   9536626.0       PMC1043971
# 290                                        NaN   9536626.0       PMC1043971
# 766                                        NaN  19348113.0       PMC2831259
# 943   http://www.nature.com/articles/srep16182  26548756.0       PMC4637828
# 2506                                       NaN   9536626.0       PMC1043971
# 2695  http://www.nature.com/articles/srep16182  26548756.0       PMC4637828
# 2773                                       NaN   9536626.0       PMC1043971
# 3925                                       NaN         NaN              NaN
# 4283                                       NaN         NaN              NaN
# 4313                                       NaN         NaN              NaN
# 5652                                       NaN         NaN              NaN
# 6054                                       NaN         NaN              NaN
# 6541                                       NaN         NaN              NaN
# 7071                                       NaN         NaN              NaN
# 8504                                       NaN   9536626.0       PMC1043971
# 8744                                       NaN   9536626.0       PMC1043971
# 8921                                       NaN         NaN              NaN
# 9710                                       NaN         NaN              NaN
#
#      Handle.net IDs          ADS Bibcode  arXiv ID RePEc ID  SSRN  URN  \
# 240             NaN                  NaN       NaN      NaN   NaN  NaN
# 290             NaN                  NaN       NaN      NaN   NaN  NaN
# 766             NaN                  NaN       NaN      NaN   NaN  NaN
# 943             NaN  2015NatSR...516182C       NaN      NaN   NaN  NaN
# 2506            NaN                  NaN       NaN      NaN   NaN  NaN
# 2695            NaN  2015NatSR...516182C       NaN      NaN   NaN  NaN
# 2773            NaN                  NaN       NaN      NaN   NaN  NaN
# 3925            NaN  2004CoMP..147..722T       NaN      NaN   NaN  NaN
# 4283            NaN  2004CoMP..147..722T       NaN      NaN   NaN  NaN
# 4313            NaN  2004CoMP..147..722T       NaN      NaN   NaN  NaN
# 5652            NaN                  NaN       NaN      NaN   NaN  NaN
# 6054            NaN                  NaN       NaN      NaN   NaN  NaN
# 6541            NaN                  NaN       NaN      NaN   NaN  NaN
# 7071            NaN                  NaN       NaN      NaN   NaN  NaN
# 8504            NaN                  NaN       NaN      NaN   NaN  NaN
# 8744            NaN                  NaN       NaN      NaN   NaN  NaN
# 8921            NaN                  NaN       NaN      NaN   NaN  NaN
# 9710            NaN                  NaN       NaN      NaN   NaN  NaN
#
#                                         Publisher Names
# 240                          Cambridge University Press
# 290                          Cambridge University Press
# 766   Duke University Press; Johns Hopkins Universit...
# 943                Scientific American; Springer Nature
# 2506                         Cambridge University Press
# 2695               Scientific American; Springer Nature
# 2773                         Cambridge University Press
# 3925                                    Springer Nature
# 4283                                    Springer Nature
# 4313                                    Springer Nature
# 5652                                    Springer Nature
# 6054                                    Springer Nature
# 6541                                    Springer Nature
# 7071                                    Springer Nature
# 8504                         Cambridge University Press
# 8744                         Cambridge University Press
# 8921                                    Springer Nature
# 9710                      Oxford University Press (OUP)
#
# [18 rows x 26 columns]
# All Mention dates are in the correct format.
# All Publication dates are in the correct format.
# Any empty URL
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time]
# Index: []
#
# [0 rows x 27 columns]
# Top 10 using Language
# Wiki_Language
# en    3832
# ja     548
# zh     478
# pt     447
# fr     406
# es     391
# de     386
# ru     386
# uk     345
# it     335
# Name: count, dtype: int64
# Last Cleaned Data
# Finish dowonload
# +++------------------------
# check unpaywall new data
# Check OA_status
# Not found OA_status
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time, Wiki_Language, OA_status, OA_Type, Genre, Title, OA_Locations, License_bestOA, University, Group]
# Index: []
#
# [0 rows x 36 columns]
# [True False 'notFound']
# There are TOTAL : 8 Data  cannot find through Unpaywall.
# There are 8 Data  cannot find through Unpaywall.
#                               DOI OA_Type
# 575     10.1136/bmjgh-2016-000260     404
# 1861      10.1136/jramc-101-02-02     404
# 2319  10.1093/gigascience/giac012     404
# 2714  10.1093/gigascience/giac012     404
# 7597      10.1136/jramc-101-02-02     404
# 9010      10.1136/jramc-101-02-02     404
# 9401      10.1136/jramc-101-02-02     404
# 9499      10.1136/jramc-101-02-02     404
# ['green' 'gold' 'hybrid' 'closed' 'bronze' 404]
#
# error data _list (Doi)
#                               DOI OA_status OA_Type  \
# 575     10.1136/bmjgh-2016-000260  notFound     404
# 1861      10.1136/jramc-101-02-02  notFound     404
# 2319  10.1093/gigascience/giac012  notFound     404
# 2714  10.1093/gigascience/giac012  notFound     404
# 7597      10.1136/jramc-101-02-02  notFound     404
# 9010      10.1136/jramc-101-02-02  notFound     404
# 9401      10.1136/jramc-101-02-02  notFound     404
# 9499      10.1136/jramc-101-02-02  notFound     404
#
#                          Mention Title
# 575                         Fred Binka
# 1861         David Bruce (mikrobiolog)
# 2319  List of sequenced animal genomes
# 2714            Biomphalaria straminea
# 7597          Девід Брюс (мікробіолог)
# 9010                       David Bruce
# 9401                   Sir David Bruce
# 9499      David Bruce (microbiologist)
# ------
# -- Cleaned Data count --
# Total catation : 9844
# University OA_ Status count
# OA_status
# True     6817
# False    3027
# Name: count, dtype: int64
# University OA_ Type count
# OA_Type
# bronze    3627
# closed    3027
# green     1348
# hybrid    1030
# gold       812
# Name: count, dtype: int64
# ------
# About truly duplicates
# There are 0 unique DOI in Duplicate list
# There are 0 unique Wiki Title in Duplicate list
# There are Total : 0 data in Duplicate list
#
# About potential duplicates
# There are 62 unique DOI in  potential Duplicate list
# There are 67 unique Wiki Title in potential Duplicate list
# There are Total : 148 data in potential Duplicate list
# De-truly Duplication Total catation : 9844
# De-potential Duplication Total catation : 9765
#
# Show all data count and percentage
#                   count  percentage  count  percentage  count  percentage
# OA_status True     6817   69.250305   6817   69.250305   6761   69.237071
#           False    3027   30.749695   3027   30.749695   3004   30.762929
# OA_Type   bronze   3627   53.205222   3627   53.205222   3605   53.320515
#           green    1348   19.774094   1348   19.774094   1337   19.775181
#           hybrid   1030   15.109286   1030   15.109286   1017   15.042154
#           gold      812   11.911398    812   11.911398    802   11.862151
# University of St Andrews_done
# ------------------------
#
# !!University of Edinburgh_Start
# Read the University of Edinburgh Alt local data file!
# trim the column
# ---Unique Numbers---
# Unique DOI counts :8055
# Unique Wiki Title counts :19332
# Total data counts :27873
# ---Check DOI ---
# There are 80 empty DOI
# In those empty DOI, there are 80 with PubMedID
# There are 0 withOUT PubMedID
# Total : 27873 data
#
# Print DOIis empty _table
#           DOI  PubMedID
# counts  27793        80
# empty      80         0
#
# ---Checking Affiliations---
# 0 data , not Uni included in Affiliations
#  List the data not include University of Edinburgh
# Empty DataFrame
# Columns: [Mention Date, Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names]
# Index: []
#
# [0 rows x 26 columns]
# All Mention dates are in the correct format.
# All Publication dates are in the correct format.
# Any empty URL
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time]
# Index: []
#
# [0 rows x 27 columns]
# Top 10 using Language
# Wiki_Language
# en    12078
# fr     1356
# ar     1227
# es     1149
# zh     1116
# it      952
# pt      936
# ja      884
# de      883
# ru      818
# Name: count, dtype: int64
# Last Cleaned Data
# Finish dowonload
# +++------------------------
# check unpaywall new data
# Check OA_status
# Not found OA_status
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time, Wiki_Language, OA_status, OA_Type, Genre, Title, OA_Locations, License_bestOA, University, Group]
# Index: []
#
# [0 rows x 36 columns]
# [True False 'notFound']
# There are TOTAL : 107 Data  cannot find through Unpaywall.
# There are 107 Data  cannot find through Unpaywall.
#                              DOI OA_Type
# 1795   10.1136/bmjgh-2016-000260     404
# 2393      10.7189/jogh.02.010406     404
# 3114                    10.1042/     404
# 4101                    10.1042/     404
# 4171      10.7189/jogh-06-010501     404
# ...                          ...     ...
# 27692                   10.1042/     404
# 27693                   10.1042/     404
# 27700                   10.1042/     404
# 27760                   10.1042/     404
# 27766                   10.1042/     404
#
# [107 rows x 2 columns]
# ['gold' 'closed' 'hybrid' 'green' 'bronze' 404]
#
# error data _list (Doi)
#                              DOI OA_status OA_Type  \
# 1795   10.1136/bmjgh-2016-000260  notFound     404
# 2393      10.7189/jogh.02.010406  notFound     404
# 3114                    10.1042/  notFound     404
# 4101                    10.1042/  notFound     404
# 4171      10.7189/jogh-06-010501  notFound     404
# ...                          ...       ...     ...
# 27692                   10.1042/  notFound     404
# 27693                   10.1042/  notFound     404
# 27700                   10.1042/  notFound     404
# 27760                   10.1042/  notFound     404
# 27766                   10.1042/  notFound     404
#
#                                         Mention Title
# 1795                                       Fred Binka
# 2393                                       Igor Rudan
# 3114                                          Archaea
# 4101                                    فيروسات جدرية
# 4171   Child Health and Nutrition Research Initiative
# ...                                               ...
# 27692                                        Thrombin
# 27693                                        Thrombin
# 27700               Nicotinamide adenine dinucleotide
# 27760                                     Ether lipid
# 27766                                   Immune system
#
# [107 rows x 4 columns]
# ------
# -- Cleaned Data count --
# Total catation : 27686
# University OA_ Status count
# OA_status
# True     19965
# False     7721
# Name: count, dtype: int64
# University OA_ Type count
# OA_Type
# closed    7721
# green     6364
# bronze    5566
# gold      4074
# hybrid    3961
# Name: count, dtype: int64
# ------
# About truly duplicates
# There are 1 unique DOI in Duplicate list
# There are 3 unique Wiki Title in Duplicate list
# There are Total : 6 data in Duplicate list
#
# About potential duplicates
# There are 235 unique DOI in  potential Duplicate list
# There are 225 unique Wiki Title in potential Duplicate list
# There are Total : 581 data in potential Duplicate list
# De-truly Duplication Total catation : 27683
# De-potential Duplication Total catation : 27374
#
# Show all data count and percentage
#                   count  percentage  count  percentage  count  percentage
# OA_status True    19965   72.112259  19965   72.120074  19718   72.031855
#           False    7721   27.887741   7718   27.879926   7656   27.968145
# OA_Type   green    6364   31.875783   6364   31.875783   6293   31.915002
#           bronze   5566   27.878788   5566   27.878788   5502   27.903438
#           gold     4074   20.405710   4074   20.405710   4009   20.331677
#           hybrid   3961   19.839720   3961   19.839720   3914   19.849883
# University of Edinburgh_done
# ------------------------
#
# !!University of Glasgow_Start
# Read the University of Glasgow Alt local data file!
# trim the column
# ---Unique Numbers---
# Unique DOI counts :4581
# Unique Wiki Title counts :10533
# Total data counts :13943
# ---Check DOI ---
# There are 56 empty DOI
# In those empty DOI, there are 56 with PubMedID
# There are 0 withOUT PubMedID
# Total : 13943 data
#
# Print DOIis empty _table
#           DOI  PubMedID
# counts  13887        56
# empty      56         0
#
# ---Checking Affiliations---
# 0 data , not Uni included in Affiliations
#  List the data not include University of Glasgow
# Empty DataFrame
# Columns: [Mention Date, Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names]
# Index: []
#
# [0 rows x 26 columns]
# All Mention dates are in the correct format.
# All Publication dates are in the correct format.
# Any empty URL
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time]
# Index: []
#
# [0 rows x 27 columns]
# Top 10 using Language
# Wiki_Language
# en    5478
# zh    1691
# ar     628
# es     572
# fr     549
# de     464
# ja     406
# pt     367
# it     355
# ru     345
# Name: count, dtype: int64
# Last Cleaned Data
# Finish dowonload
# +++------------------------
# check unpaywall new data
# Check OA_status
# Not found OA_status
# Empty DataFrame
# Columns: [Mention Title, Mention URL, Research Output Title, Journal/Collection Title, Authors at my Institution, Departments, Output Type, Subjects (FoR), Affiliations (GRID), Publication Date, Altmetric Attention Score, Details Page URL, DOI, ISBN, National Clinical Trial ID, URI, PubMed ID, PubMedCentral ID, Handle.net IDs, ADS Bibcode, arXiv ID, RePEc ID, SSRN, URN, Publisher Names, Mention_date, Mention_time, Wiki_Language, OA_status, OA_Type, Genre, Title, OA_Locations, License_bestOA, University, Group]
# Index: []
#
# [0 rows x 36 columns]
# [True False 'notFound']
# There are TOTAL : 15 Data  cannot find through Unpaywall.
# There are 15 Data  cannot find through Unpaywall.
#                                  DOI OA_Type
# 2311                 013166/aim.0010     404
# 5305              10.1192/bjp.02.286     404
# 6838   10.3233/978-1-60750-583-9-259     404
# 8388           10.1136/vr.161.25.858     404
# 8594                 013166/aim.0010     404
# 9230           10.1136/vr.147.23.661     404
# 9695   10.3233/978-1-60750-583-9-259     404
# 9938                 013166/aim.0010     404
# 11185  10.3233/978-1-60750-583-9-259     404
# 11214  10.3233/978-1-60750-583-9-259     404
# 11527                013166/aim.0010     404
# 11570                013166/aim.0010     404
# 12071  10.3233/978-1-60750-583-9-259     404
# 12157  10.3233/978-1-60750-583-9-259     404
# 12300          10.1136/vr.161.25.858     404
# ['bronze' 'closed' 'green' 'gold' 'hybrid' 404]
#
# error data _list (Doi)
#                                  DOI OA_status OA_Type  \
# 2311                 013166/aim.0010  notFound     404
# 5305              10.1192/bjp.02.286  notFound     404
# 6838   10.3233/978-1-60750-583-9-259  notFound     404
# 8388           10.1136/vr.161.25.858  notFound     404
# 8594                 013166/aim.0010  notFound     404
# 9230           10.1136/vr.147.23.661  notFound     404
# 9695   10.3233/978-1-60750-583-9-259  notFound     404
# 9938                 013166/aim.0010  notFound     404
# 11185  10.3233/978-1-60750-583-9-259  notFound     404
# 11214  10.3233/978-1-60750-583-9-259  notFound     404
# 11527                013166/aim.0010  notFound     404
# 11570                013166/aim.0010  notFound     404
# 12071  10.3233/978-1-60750-583-9-259  notFound     404
# 12157  10.3233/978-1-60750-583-9-259  notFound     404
# 12300          10.1136/vr.161.25.858  notFound     404
#
#                              Mention Title
# 2311                            Рак желуца
# 5305   Scottish inventions and discoveries
# 6838                          Dengue fever
# 8388      Bovine malignant catarrhal fever
# 8594                   পাকস্থলীর ক্যান্সার
# 9230                           Horse colic
# 9695                          Dengue fever
# 9938                                    胃癌
# 11185                            حمى الضنك
# 11214                                 骨痛熱症
# 11527                 Tumore dello stomaco
# 11570                       Stomach cancer
# 12071                                Denga
# 12157                               Dengue
# 12300            Fièvre catarrhale maligne
# ------
# -- Cleaned Data count --
# Total catation : 13872
# University OA_ Status count
# OA_status
# True     9547
# False    4325
# Name: count, dtype: int64
# University OA_ Type count
# OA_Type
# closed    4325
# hybrid    3523
# green     2409
# bronze    2299
# gold      1316
# Name: count, dtype: int64
# ------
# About truly duplicates
# There are 0 unique DOI in Duplicate list
# There are 0 unique Wiki Title in Duplicate list
# There are Total : 0 data in Duplicate list
#
# About potential duplicates
# There are 114 unique DOI in  potential Duplicate list
# There are 105 unique Wiki Title in potential Duplicate list
# There are Total : 261 data in potential Duplicate list
# De-truly Duplication Total catation : 13872
# De-potential Duplication Total catation : 13735
#
# Show all data count and percentage
#                   count  percentage  count  percentage  count  percentage
# OA_status True     9547   68.822088   9547   68.822088   9451   68.809610
#           False    4325   31.177912   4325   31.177912   4284   31.190390
# OA_Type   hybrid   3523   36.901644   3523   36.901644   3504   37.075442
#           green    2409   25.233058   2409   25.233058   2375   25.129616
#           bronze   2299   24.080863   2299   24.080863   2276   24.082108
#           gold     1316   13.784435   1316   13.784435   1296   13.712835
# University of Glasgow_done
# ------------------------

# %% [markdown]
# # More
#
# ---

# %%
# # plt.plot(New_data["Mention_date"], label='All ' ,linestyle = 'dashed')
# plt.hist(Stirling_New_data["Mention_date"], alpha=0.5, label='All Patients', color='grey')
#     # Legend
# plt.legend(loc=0)

# # titles and labels
# plt.title(f'wikiOpencite : "Mention_date"')
# # plt.xlabel(category)
# plt.ylabel('Frequency')
